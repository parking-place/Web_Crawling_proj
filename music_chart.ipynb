# %%
import pandas as pd

melon_chart = pd.read_csv('./Data/2023-04-26-16_melon.csv', index_col='rank')
melon_chart
# Out:
#                      title           singer
# rank
# 1                     I AM        IVE (아이브)  \
# 2                   Kitsch        IVE (아이브)
# 3                        꽃       지수 (JISOO)
# 4                      손오공  세븐틴 (SEVENTEEN)
# 5      파이팅 해야지 (Feat. 이영지)  부석순 (SEVENTEEN)
# ...                    ...              ...
# 96     Young, Dumb, Stupid            NMIXX
# 97                다시 사랑한다면              한동근
# 98    후유증 (Can We Go Back)          NCT 도재정
# 99             Off My Face    Justin Bieber
# 100                 Unholy        Sam Smith
#
#                                    album
# rank
# 1                               I've IVE
# 2                               I've IVE
# 3                                     ME
# 4        SEVENTEEN 10th Mini Album ‘FML'
# 5     부석순 1st Single Album 'SECOND WIND'
# ...                                  ...
# 96                               expérgo
# 97                              다시 사랑한다면
# ...

# %%
bugs_chart = pd.read_csv('./Data/2023-04-26-16_bugs.csv', index_col='rank')
bugs_chart
# Out:
#                                title           singer
# rank
# 1                               I AM        IVE (아이브)  \
# 2                             Kitsch        IVE (아이브)
# 3                                  꽃        지수(JISOO)
# 4                              Cupid      FIFTY FIFTY
# 5                              Ditto         NewJeans
# ...                              ...              ...
# 96                 자격지심 (Feat. ZICO)        BE'O (비오)
# 97                            Rising  tripleS (트리플에스)
# 98    I Don't Understand But I Luv U   세븐틴(SEVENTEEN)
# 99      Inspiration (feat. Beenzino)               태양
# 100                그댄 행복에 살텐데 (2022)              최유리
#
#                                 album
# rank
# 1                            I've IVE
# 2                            I've IVE
# 3                                  ME
# 4                The Beginning: Cupid
# 5                      NewJeans 'OMG'
# ...                               ...
# ...

# %%
genie_chart = pd.read_csv('./Data/2023-04-26-16_genie.csv', index_col='rank')
genie_chart[:100]
# Out:
#                                 title         singer
# rank
# 1                                I AM      IVE (아이브)  \
# 2                              Kitsch      IVE (아이브)
# 3                                   꽃     지수 (JISOO)
# 4                               Ditto       NewJeans
# 5                            Hype boy       NewJeans
# ...                               ...            ...
# 96    Rush Hour (Feat. j-hope of BTS)          Crush
# 97                     밤하늘의 별을 (2020)             경서
# 98         너의 번호를 누르고 (Prod. by 영화처럼)            #안녕
# 99                        Off My Face  Justin Bieber
# 100                               신호등            이무진
#
#                             album
# rank
# 1                        I've IVE
# 2                        I've IVE
# 3                              ME
# 4                  NewJeans 'OMG'
# 5     NewJeans 1st EP 'New Jeans'
# ...                           ...
# 96                      Rush Hour
# ...
