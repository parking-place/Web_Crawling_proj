# %%
import pandas as pd

melon_chart = pd.read_csv('./Data/2023-04-26-15_melon.csv', index_col='rank')
melon_chart
# Out:
#                      title           singer
# rank
# 1                     I AM        IVE (아이브)  \
# 2                   Kitsch        IVE (아이브)
# 3                        꽃       지수 (JISOO)
# 4                      손오공  세븐틴 (SEVENTEEN)
# 5      파이팅 해야지 (Feat. 이영지)  부석순 (SEVENTEEN)
# ...                    ...              ...
# 96    후유증 (Can We Go Back)          NCT 도재정
# 97     Young, Dumb, Stupid            NMIXX
# 98                다시 사랑한다면              한동근
# 99                  Unholy        Sam Smith
# 100            Off My Face    Justin Bieber
#
#                                    album
# rank
# 1                               I've IVE
# 2                               I've IVE
# 3                                     ME
# 4        SEVENTEEN 10th Mini Album ‘FML'
# 5     부석순 1st Single Album 'SECOND WIND'
# ...                                  ...
# 96          Perfume - The 1st Mini Album
# 97                               expérgo
# ...

# %%
bugs_chart = pd.read_csv('./Data/2023-04-26-15_bugs.csv', index_col='rank')
bugs_chart
# Out:
#                                                   title          singer
# rank
# 1                                                  I AM       IVE (아이브)  \
# 2                                                Kitsch       IVE (아이브)
# 3                                                     꽃       지수(JISOO)
# 4                                                 Cupid     FIFTY FIFTY
# 5                                                   손오공  세븐틴(SEVENTEEN)
# ...                                                 ...             ...
# 96                                         Heaven(2023)             임재현
# 97                                      도깨비불 (Illusion)           aespa
# 98    Dreamers [Music from the FIFA World Cup Qatar ...              정국
# 99                       I Don't Understand But I Luv U  세븐틴(SEVENTEEN)
# 100                                             사랑하기 싫어         지아(Zia)
#
#                                                   album
# rank
# ...

# %%
genie_chart = pd.read_csv('./Data/2023-04-26-15_genie.csv', index_col='rank')
genie_chart[:100]
# Out:
#                              title        singer                        album
# rank
# 1                             I AM     IVE (아이브)                     I've IVE
# 2                           Kitsch     IVE (아이브)                     I've IVE
# 3                                꽃    지수 (JISOO)                           ME
# 4                            Ditto      NewJeans               NewJeans 'OMG'
# 5                         Hype boy      NewJeans  NewJeans 1st EP 'New Jeans'
# ...                            ...           ...                          ...
# 96                      그중에 그대를 만나           김호중         삼남매가 용감하게 OST Part.1
# 97            봄여름가을겨울 (Still Life)  BIGBANG (빅뱅)         봄여름가을겨울 (Still Life)
# 98                    Every Second    Mina Okabe                 Every Second
# 99                    사랑하지 않아서 그랬어           임한별                 사랑하지 않아서 그랬어
# 100   슝! (Feat. LISA of BLACKPINK)            태양                Down to Earth
#
# [100 rows x 3 columns]
